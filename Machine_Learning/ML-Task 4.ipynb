# %% [markdown]
# ## Task - 4p
#
# * **Name :** M.Rachel
# * **Student No. :** 224234147
# * **Deakin Mail :** s224234147@deakin.edu.au
# * **Email Address:** rachelriney1608@gmail.com

# %% [markdown]
# ### Problem Statement
#
# The dataset describes it is a local stability analysis of 4-node star system. It is electricity producer implements the decentral smart grid control concept. It has 12 features and 10000 instances.
#
# ### Features
# * **tau1,tau2,tau3,tau4**- reaction times (Tau) of the grid participants to changing grid conditions
# * **p1,p2,p3,p4**- the volumes of electricity consumed / produced (P) by each grid participant
# * **g1,g2,g3,g4**- cost-sensitivity (G)
#
# ### Target variables
#
# * **stab,stabf** - grid stability

# %%
# Import Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### 1. Download Electrical Grid Stability Simulated Data dataset and print the dimension of the dataset.

# %%
#Loading the dataset
df = pd.read_csv("F:/Data Science/Datasets/Data_for_UCI_named.csv")

# %%
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
# Dimensions of the dataset
df.shape
# Out:
# (10000, 14)

# %%
# Describe the dataset
df.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %%
# Information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
# Checking missing values
df.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %% [markdown]
# * From the data describe we found there is no missing values.
# * Lets check the skewness.

# %% [markdown]
# #### 2. Classify the "Electrical Grid Stability Simulated Data" (target=stabf) available in the dataset using SVM with three different kernels. Select appropriate data splitting approach and performance metrics. Report the performances and the used model hyper-parameters.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df.drop(columns=['stabf'])
y = df['stabf']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# Three different kernals 'linear','poly','rbf'
svm_linear = SVC(kernel='linear', random_state=42)
svm_poly = SVC(kernel='poly', random_state=42)
svm_rbf = SVC(kernel='rbf', random_state=42)

# Train the models
svm_linear.fit(X_train, y_train)
svm_poly.fit(X_train, y_train)
svm_rbf.fit(X_train, y_train)

# Predicting the models
y_pred_linear = svm_linear.predict(X_test)
y_pred_poly = svm_poly.predict(X_test)
y_pred_rbf = svm_rbf.predict(X_test)

# %%
# Evaluation metrics
def evaluate_model(y_test, y_pred, model_name):
    print(f"Performance for {model_name}:")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("\n")

# Report performance
evaluate_model(y_test, y_pred_linear, 'SVM with Linear Kernel')
evaluate_model(y_test, y_pred_poly, 'SVM with Polynomial Kernel')
evaluate_model(y_test, y_pred_rbf, 'SVM with RBF Kernel')
# Out:
# Performance for SVM with Linear Kernel:
# Accuracy: 0.9973333333333333
#               precision    recall  f1-score   support
#
#       stable       1.00      1.00      1.00      1086
#     unstable       1.00      1.00      1.00      1914
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
#
#
# Performance for SVM with Polynomial Kernel:
# Accuracy: 0.9743333333333334
#               precision    recall  f1-score   support
#
#       stable       0.98      0.95      0.96      1086
#     unstable       0.97      0.99      0.98      1914
#
#     accuracy                           0.97      3000
#    macro avg       0.97      0.97      0.97      3000
# weighted avg       0.97      0.97      0.97      3000
#
#
#
# Performance for SVM with RBF Kernel:
# Accuracy: 0.9866666666666667
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# #### 3. Continue from question 2, use the same training and test set, use KNN and tune K on the training set, report the performance on the test set and the optimal K.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

# Define the parameter grid for KNN (we'll tune K)
param_grid_knn = {'n_neighbors': list(range(1, 31))}

# Initialize the KNN model
knn = KNeighborsClassifier()

# Grid search to find the best value of K
grid_knn = GridSearchCV(knn, param_grid_knn, cv=5, scoring='accuracy')

# Fit the model
grid_knn.fit(X_train, y_train)

# Best model
best_knn = grid_knn.best_estimator_

# Predict on the test set with the best KNN model
y_pred_best_knn = best_knn.predict(X_test)

# Evaluate the best KNN model
print("Optimal K:", grid_knn.best_params_)
evaluate_model(y_test, y_pred_best_knn, 'Best KNN')

# Report the classification report
print("Classification Report for Best KNN Model:")
print(classification_report(y_test, y_pred_best_knn))
# Out:
# Optimal K: {'n_neighbors': 22}
# Performance for Best KNN:
# Accuracy: 0.9536666666666667
#               precision    recall  f1-score   support
#
#       stable       0.96      0.91      0.93      1086
#     unstable       0.95      0.98      0.96      1914
#
#     accuracy                           0.95      3000
#    macro avg       0.96      0.94      0.95      3000
# weighted avg       0.95      0.95      0.95      3000
#
#
#
# Classification Report for Best KNN Model:
#               precision    recall  f1-score   support
#
#       stable       0.96      0.91      0.93      1086
#     unstable       0.95      0.98      0.96      1914
#
#     accuracy                           0.95      3000
#    macro avg       0.96      0.94      0.95      3000
# weighted avg       0.95      0.95      0.95      3000

# %% [markdown]
# #### 4. Continue from question 2, use the same training and test set, use Decision Tree and tune the depth of the tree on the training set, report the performance on the test set and the optimal depth.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

# Define the parameter grid for Decision Tree (we'll tune the max depth)
param_grid_dt = {'max_depth': list(range(1, 21))}

# Initialize the Decision Tree model
dt = DecisionTreeClassifier(random_state=42)

# Grid search to find the best max depth
grid_dt = GridSearchCV(dt, param_grid_dt, cv=5, scoring='accuracy')

# Fit the model
grid_dt.fit(X_train, y_train)

# Best model
best_dt = grid_dt.best_estimator_

# Predict on the test set with the best Decision Tree model
y_pred_best_dt = best_dt.predict(X_test)

# Evaluate the best Decision Tree model
print("Optimal Depth:", grid_dt.best_params_)
evaluate_model(y_test, y_pred_best_dt, 'Best Decision Tree')

# Report the classification report
print("Classification Report for Best Decision Tree Model:")
print(classification_report(y_test, y_pred_best_dt))
# Out:
# Optimal Depth: {'max_depth': 1}
# Performance for Best Decision Tree:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       stable       1.00      1.00      1.00      1086
#     unstable       1.00      1.00      1.00      1914
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
#
#
# Classification Report for Best Decision Tree Model:
#               precision    recall  f1-score   support
#
#       stable       1.00      1.00      1.00      1086
#     unstable       1.00      1.00      1.00      1914
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %% [markdown]
# #### 5. Based on the model hyper-parameters used in question 2, 3 and question 4, share your understanding of hyper-parameters tuning in ML model development.

# %% [markdown]
# * From the performances SVM kernal RBF performed better
# * KNN neighbors the machine chose best K-neighbors that made model performed better.
# * In decision tree through hyperparameter tuning the machine chose best parameter for max_depth that made model performed better.

# %% [markdown]
# ## REFERENCES
#
# 1) “UCI Machine Learning Repository,” archive.ics.uci.edu. https://archive.ics.uci.edu/dataset/471/electrical+grid+stability+simulated+data
